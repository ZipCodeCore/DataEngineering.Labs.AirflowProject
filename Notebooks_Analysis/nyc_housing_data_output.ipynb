# %%
# Parameters
file_name = "/Users/nli/dev/airflow_home/data/nyc_housing_data2.csv"

# %%
import numpy
import pandas as pd

# %%
# NYC public housing data
"""
We will collect and use the location of NYC public housing data (based on borough) in this dataset.
"""
nyc_housing_df=pd.read_csv('/Users/nli/dev/airflow_home/data/nyc_housing_data.csv')

# %%
nyc_housing_df.shape
# Out:
# (4384, 42)

# %%
 nyc_housing_df.head()
# Out:
#    Project ID                                 Project Name  \
# 0       68894    HP HUTCHINSON RIVER PARKWAY HDFC.HPO.FY20
# 1       67286  ROCKAWAY VILLAGE PHASE 1B (RITA STARK SITE)
# 2       67286  ROCKAWAY VILLAGE PHASE 1B (RITA STARK SITE)
# 3       67693                      680 ST. NICHOLAS AVENUE
# 4       67693                      680 ST. NICHOLAS AVENUE
#
#                  Program Group Project Start Date Project Completion Date  \
# 0  Multifamily Finance Program         12/31/2019              12/31/2019
# 1  Multifamily Finance Program         12/30/2019                     NaN
# 2  Multifamily Finance Program         12/30/2019                     NaN
# 3  Multifamily Finance Program         12/30/2019              12/30/2019
# 4  Multifamily Finance Program         12/30/2019              12/30/2019
#
#    Building ID Number                    Street    Borough  Postcode  ...  \
# 0     942897.0   1632  HUTCHINSON RIVER PARKWAY      Bronx   10461.0  ...
# ...

# %%
 nyc_housing_df.tail()
# Out:
#       Project ID  Project Name                 Program Group  \
# 4379       55697  CONFIDENTIAL  Homeowner Assistance Program
# 4380       55773  CONFIDENTIAL  Homeowner Assistance Program
# 4381       57341  CONFIDENTIAL  Homeowner Assistance Program
# 4382       55647  CONFIDENTIAL  Homeowner Assistance Program
# 4383       55759  CONFIDENTIAL  Homeowner Assistance Program
#
#      Project Start Date Project Completion Date  Building ID Number Street  \
# 4379         01/14/2014              01/14/2014          NaN   ----   ----
# 4380         01/10/2014              01/10/2014          NaN   ----   ----
# 4381         01/10/2014              01/10/2014          NaN   ----   ----
# 4382         01/07/2014              01/07/2014          NaN   ----   ----
# 4383         01/03/2014              01/03/2014          NaN   ----   ----
#
#             Borough  Postcode  ...  2-BR Units  3-BR Units 4-BR Units  \
# 4379       Brooklyn       NaN  ...           0           0          0
# ...

# %%
nyc_housing_df.shape
# Out:
# (4384, 42)

# %%
nyc_housing_df.count()
# Out:
# Project ID                            4384
# Project Name                          4384
# Program Group                         4384
# Project Start Date                    4384
# Project Completion Date               3163
# Building ID                           3440
# Number                                4384
# Street                                4384
# Borough                               4384
# Postcode                              3405
# BBL                                   3362
# BIN                                   3046
# Community Board                       4384
# Council District                      4375
# Census Tract                          3411
# NTA - Neighborhood Tabulation Area    3411
# Latitude                              3405
# Longitude                             3405
# Latitude (Internal)                   3356
# Longitude (Internal)                  3356
# Building Completion Date              3285
# Reporting Construction Type           4384
# ...

# %%
#Summary of missing data
nyc_housing_df.isnull().sum()
# Out:
# Project ID                               0
# Project Name                             0
# Program Group                            0
# Project Start Date                       0
# Project Completion Date               1221
# Building ID                            944
# Number                                   0
# Street                                   0
# Borough                                  0
# Postcode                               979
# BBL                                   1022
# BIN                                   1338
# Community Board                          0
# Council District                         9
# Census Tract                           973
# NTA - Neighborhood Tabulation Area     973
# Latitude                               979
# Longitude                              979
# Latitude (Internal)                   1028
# Longitude (Internal)                  1028
# Building Completion Date              1099
# Reporting Construction Type              0
# ...

# %%
nyc_housing_df.columns
# Out:
# Index(['Project ID', 'Project Name', 'Program Group', 'Project Start Date',
#        'Project Completion Date', 'Building ID', 'Number', 'Street', 'Borough',
#        'Postcode', 'BBL', 'BIN', 'Community Board', 'Council District',
#        'Census Tract', 'NTA - Neighborhood Tabulation Area', 'Latitude',
#        'Longitude', 'Latitude (Internal)', 'Longitude (Internal)',
#        'Building Completion Date', 'Reporting Construction Type',
#        'Extended Affordability Only', 'Prevailing Wage Status',
#        'Extremely Low Income Units', 'Very Low Income Units',
#        'Low Income Units', 'Moderate Income Units', 'Middle Income Units',
#        'Other Income Units', 'Studio Units', '1-BR Units', '2-BR Units',
#        '3-BR Units', '4-BR Units', '5-BR Units', '6-BR+ Units',
#        'Unknown-BR Units', 'Counted Rental Units',
#        'Counted Homeownership Units', 'All Counted Units', 'Total Units'],
#       dtype='object')

# %%
nyc_housing_df2 = nyc_housing_df.drop(columns=['Program Group', 'Project Name', 'Project Start Date', 'Project Completion Date',
                           'Building ID','Number', 'Street','Postcode','BBL', 'BIN', 'Community Board', 'Council District',
                           'Census Tract', 'NTA - Neighborhood Tabulation Area','Latitude (Internal)', 
                            'Longitude (Internal)', 'Building Completion Date','Reporting Construction Type', 
                            'Extended Affordability Only', 'Prevailing Wage Status','Studio Units','1-BR Units', 
                            '2-BR Units', '3-BR Units', '4-BR Units', '5-BR Units','6-BR+ Units','Unknown-BR Units',
                            'Counted Rental Units', 'Counted Homeownership Units','All Counted Units'])

# %%
nyc_housing_df2
# Out:
#       Project ID        Borough   Latitude  Longitude  \
# 0          68894          Bronx  40.844284 -73.836606
# 1          67286         Queens  40.604427 -73.753203
# 2          67286         Queens  40.604334 -73.752998
# 3          67693      Manhattan  40.823321 -73.945088
# 4          67693      Manhattan  40.823823 -73.944289
# ...          ...            ...        ...        ...
# 4379       55697       Brooklyn        NaN        NaN
# 4380       55773  Staten Island        NaN        NaN
# 4381       57341  Staten Island        NaN        NaN
# 4382       55647       Brooklyn        NaN        NaN
# 4383       55759         Queens        NaN        NaN
#
#       Extremely Low Income Units  Very Low Income Units  Low Income Units  \
# 0                              0                      0                44
# 1                             24                     92               114
# 2                              8                     34                43
# ...

# %%
nyc_housing_df2_wo_ll= nyc_housing_df2.drop(columns=['Latitude', 'Longitude'])

# %%
nyc_housing_df2_wo_ll.head()
# Out:
#    Project ID    Borough  Extremely Low Income Units  Very Low Income Units  \
# 0       68894      Bronx                           0                      0
# 1       67286     Queens                          24                     92
# 2       67286     Queens                           8                     34
# 3       67693  Manhattan                          49                      8
# 4       67693  Manhattan                          36                      8
#
#    Low Income Units  Moderate Income Units  Middle Income Units  \
# 0                44                      0                    0
# 1               114                      0                    0
# 2                43                      0                    0
# 3                 2                      1                    0
# 4                 3                      4                    0
#
#    Other Income Units  Total Units
# 0                   0           44
# 1                   1          231
# ...

# %%
nyc_housing_df3 = nyc_housing_df2.dropna()

# %%
#for heat map
nyc_housing_df3.head()
# Out:
#    Project ID    Borough   Latitude  Longitude  Extremely Low Income Units  \
# 0       68894      Bronx  40.844284 -73.836606                           0
# 1       67286     Queens  40.604427 -73.753203                          24
# 2       67286     Queens  40.604334 -73.752998                           8
# 3       67693  Manhattan  40.823321 -73.945088                          49
# 4       67693  Manhattan  40.823823 -73.944289                          36
#
#    Very Low Income Units  Low Income Units  Moderate Income Units  \
# 0                      0                44                      0
# 1                     92               114                      0
# 2                     34                43                      0
# 3                      8                 2                      1
# 4                      8                 3                      4
#
#    Middle Income Units  Other Income Units  Total Units
# 0                    0                   0           44
# ...

# %%
# For this data, we only use borough information
nyc_housing_df.Borough.count()
# Out:
# 4384

# %%
#Totdal boroughes number
nyc_housing_df.Borough.nunique()
# Out:
# 5

# %%
# Groupby borough
nyc_housing_df.groupby('Borough').count()
# Out:
#                Project ID  Project Name  Program Group  Project Start Date  \
# Borough
# Bronx                1008          1008           1008                1008
# Brooklyn             1862          1862           1862                1862
# Manhattan             802           802            802                 802
# Queens                491           491            491                 491
# Staten Island         221           221            221                 221
#
#                Project Completion Date  Building ID  Number  Street  Postcode  \
# Borough
# Bronx                              731          808    1008    1008       802
# Brooklyn                          1278         1593    1862    1862      1576
# Manhattan                          574          789     802     802       787
# Queens                             369          228     491     491       218
# Staten Island                      211           22     221     221        22
#
# ...

# %%
# Only count borough
nyc_housing_df.groupby('Borough').Borough.count()
# Out:
# Borough
# Bronx            1008
# Brooklyn         1862
# Manhattan         802
# Queens            491
# Staten Island     221
# Name: Borough, dtype: int64

# %%
# we can browser about the housing list by chaning the borough name (Manhattan, Brooklyn, Queens, Bronx, Stand Island)
nyc_housing_df.loc[nyc_housing_df["Borough"] == "Manhattan"]
# Out:
#       Project ID                                   Project Name  \
# 3          67693                        680 ST. NICHOLAS AVENUE
# 4          67693                        680 ST. NICHOLAS AVENUE
# 5          68188         WEST 141ST STREET CLUSTER.PILLARS.FY20
# 6          68188         WEST 141ST STREET CLUSTER.PILLARS.FY20
# 36         65563      LES 278 HDFC.PLP.FY20 (278 EAST 7 STREET)
# ...          ...                                            ...
# 4293       52436  153 Manhattan Ave HDFC Extended Affordability
# 4295       65123                                      THE STACK
# 4321       49588          My Micro NY fka Adapt NYC/Micro Units
# 4334       50392                           Promenade Apartments
# 4368       50682                              74 W 105th Street
#
#                        Program Group Project Start Date  \
# 3        Multifamily Finance Program         12/30/2019
# 4        Multifamily Finance Program         12/30/2019
# ...

# %%
nyc_housing_df_boro_summaries = nyc_housing_df.groupby('Borough').Borough.count()

# %%
nyc_housing_df_boro_summaries
# Out:
# Borough
# Bronx            1008
# Brooklyn         1862
# Manhattan         802
# Queens            491
# Staten Island     221
# Name: Borough, dtype: int64

# %%
nyc_housing_df_boro_summaries.to_csv('nyc_h_sum.csv')
# Out:
# /Users/nli/opt/anaconda3/envs/airflow/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
