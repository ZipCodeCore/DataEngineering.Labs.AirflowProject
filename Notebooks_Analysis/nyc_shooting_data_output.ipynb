# %%
# Parameters
file_name = "/Users/nli/dev/airflow_home/data/nyc_park2.csv"

# %%
import pandas as pd
import os
import json

# %%
# NYC shooting data
nyc_shooting_df=pd.read_csv('/Users/nli/dev/airflow_home/data/nyc_shooting_data.csv')

# %%
nyc_shooting_df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  \
# 0     206890929  12/31/2019   23:15:00  MANHATTAN        28
# 1     206891917  12/31/2019   20:14:00   BROOKLYN        73
# 2     206882664  12/30/2019   21:29:00   BROOKLYN        71
# 3     206875589  12/30/2019   03:17:00   BROOKLYN        81
# 4     206875589  12/30/2019   03:17:00   BROOKLYN        81
#
#    JURISDICTION_CODE LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  \
# 0                0.0   HOTEL/MOTEL                     True          25-44
# 1                0.0           NaN                    False            NaN
# 2                0.0           NaN                    False          25-44
# 3                0.0           NaN                    False            NaN
# 4                0.0           NaN                    False            NaN
#
#   PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX        VIC_RACE  X_COORD_CD  \
# 0        M     BLACK         25-44       M           BLACK      997155
# ...

# %%
nyc_shooting_df.tail()
# Out:
#      INCIDENT_KEY  OCCUR_DATE OCCUR_TIME      BORO  PRECINCT  \
# 962     191851037  01/03/2019   21:00:00     BRONX        49
# 963     191790873  01/02/2019   13:34:00  BROOKLYN        79
# 964     191739125  01/01/2019   05:40:00  BROOKLYN        88
# 965     191709964  01/01/2019   04:26:00  BROOKLYN        75
# 966     191739126  01/01/2019   02:19:00     BRONX        46
#
#      JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 962                0.0                        NaN                    False
# 963                2.0  MULTI DWELL - PUBLIC HOUS                    False
# 964                2.0  MULTI DWELL - PUBLIC HOUS                    False
# 965                2.0  MULTI DWELL - PUBLIC HOUS                     True
# 966                2.0    MULTI DWELL - APT BUILD                    False
#
#     PERP_AGE_GROUP PERP_SEX       PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 962            NaN      NaN             NaN         25-44       M
# ...

# %%
nyc_shooting_df.shape
# Out:
# (967, 18)

# %%
nyc_shooting_df.columns
# Out:
# Index(['INCIDENT_KEY', 'OCCUR_DATE', 'OCCUR_TIME', 'BORO', 'PRECINCT',
#        'JURISDICTION_CODE', 'LOCATION_DESC', 'STATISTICAL_MURDER_FLAG',
#        'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'VIC_AGE_GROUP', 'VIC_SEX',
#        'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
nyc_shooting_df.count()
# Out:
# INCIDENT_KEY               967
# OCCUR_DATE                 967
# OCCUR_TIME                 967
# BORO                       967
# PRECINCT                   967
# JURISDICTION_CODE          966
# LOCATION_DESC              321
# STATISTICAL_MURDER_FLAG    967
# PERP_AGE_GROUP             519
# PERP_SEX                   519
# PERP_RACE                  519
# VIC_AGE_GROUP              967
# VIC_SEX                    967
# VIC_RACE                   967
# X_COORD_CD                 967
# Y_COORD_CD                 967
# Latitude                   967
# Longitude                  967
# dtype: int64

# %%
nyc_shooting_df.isnull().sum()
# Out:
# INCIDENT_KEY                 0
# OCCUR_DATE                   0
# OCCUR_TIME                   0
# BORO                         0
# PRECINCT                     0
# JURISDICTION_CODE            1
# LOCATION_DESC              646
# STATISTICAL_MURDER_FLAG      0
# PERP_AGE_GROUP             448
# PERP_SEX                   448
# PERP_RACE                  448
# VIC_AGE_GROUP                0
# VIC_SEX                      0
# VIC_RACE                     0
# X_COORD_CD                   0
# Y_COORD_CD                   0
# Latitude                     0
# Longitude                    0
# dtype: int64

# %%
nyc_shooting_df.groupby('BORO').count()
# Out:
#                INCIDENT_KEY  OCCUR_DATE  OCCUR_TIME  PRECINCT  \
# BORO
# BRONX                   266         266         266       266
# BROOKLYN                372         372         372       372
# MANHATTAN               145         145         145       145
# QUEENS                  158         158         158       158
# STATEN ISLAND            26          26          26        26
#
#                JURISDICTION_CODE  LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# BORO
# BRONX                        266             78                      266
# BROOKLYN                     372            136                      372
# MANHATTAN                    144             63                      145
# QUEENS                       158             40                      158
# STATEN ISLAND                 26              4                       26
#
#                PERP_AGE_GROUP  PERP_SEX  PERP_RACE  VIC_AGE_GROUP  VIC_SEX  \
# BORO
# ...

# %%
nyc_shooting_df.groupby('BORO').BORO.count()
# Out:
# BORO
# BRONX            266
# BROOKLYN         372
# MANHATTAN        145
# QUEENS           158
# STATEN ISLAND     26
# Name: BORO, dtype: int64

# %%
#Rename the BORO -> Borough, prepare for join table later
nyc_shooting_df.rename(columns={'BORO':"Borough"}, inplace=True)

# %%
nyc_shooting_df
# Out:
#      INCIDENT_KEY  OCCUR_DATE OCCUR_TIME    Borough  PRECINCT  \
# 0       206890929  12/31/2019   23:15:00  MANHATTAN        28
# 1       206891917  12/31/2019   20:14:00   BROOKLYN        73
# 2       206882664  12/30/2019   21:29:00   BROOKLYN        71
# 3       206875589  12/30/2019   03:17:00   BROOKLYN        81
# 4       206875589  12/30/2019   03:17:00   BROOKLYN        81
# ..            ...         ...        ...        ...       ...
# 962     191851037  01/03/2019   21:00:00      BRONX        49
# 963     191790873  01/02/2019   13:34:00   BROOKLYN        79
# 964     191739125  01/01/2019   05:40:00   BROOKLYN        88
# 965     191709964  01/01/2019   04:26:00   BROOKLYN        75
# 966     191739126  01/01/2019   02:19:00      BRONX        46
#
#      JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                  0.0                HOTEL/MOTEL                     True
# ...

# %%
nyc_shooting_df2 = nyc_shooting_df.drop(columns=['INCIDENT_KEY', 'JURISDICTION_CODE', 'LOCATION_DESC', 
                                                'STATISTICAL_MURDER_FLAG', 'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE',
                                                'VIC_AGE_GROUP', 'VIC_AGE_GROUP', 'VIC_RACE', 
                                                 'X_COORD_CD', 'Y_COORD_CD'])

# %%
nyc_shooting_df2.head()
# Out:
#    OCCUR_DATE OCCUR_TIME    Borough  PRECINCT VIC_SEX   Latitude  Longitude
# 0  12/31/2019   23:15:00  MANHATTAN        28       M  40.800244 -73.953390
# 1  12/31/2019   20:14:00   BROOKLYN        73       M  40.660527 -73.917156
# 2  12/30/2019   21:29:00   BROOKLYN        71       M  40.656923 -73.939647
# 3  12/30/2019   03:17:00   BROOKLYN        81       M  40.686815 -73.919370
# 4  12/30/2019   03:17:00   BROOKLYN        81       M  40.686815 -73.919370

# %%
nyc_shooting_df2.isnull().sum()
# Out:
# OCCUR_DATE    0
# OCCUR_TIME    0
# Borough       0
# PRECINCT      0
# VIC_SEX       0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
nyc_shooting_df2.columns = ['occur_date', 'occur_time', 'borough', 'precinct', 'vic_sex','latitude', 'longitude']

# %%
nyc_shooting_df2.head()
# Out:
#    occur_date occur_time    borough  precinct vic_sex   latitude  longitude
# 0  12/31/2019   23:15:00  MANHATTAN        28       M  40.800244 -73.953390
# 1  12/31/2019   20:14:00   BROOKLYN        73       M  40.660527 -73.917156
# 2  12/30/2019   21:29:00   BROOKLYN        71       M  40.656923 -73.939647
# 3  12/30/2019   03:17:00   BROOKLYN        81       M  40.686815 -73.919370
# 4  12/30/2019   03:17:00   BROOKLYN        81       M  40.686815 -73.919370

# %%
nyc_shooting_df2.to_csv('/Users/nli/dev/airflow_home/data/nyc_shooting_data2.csv')
